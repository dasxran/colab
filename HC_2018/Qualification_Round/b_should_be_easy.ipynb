317 840 328 492 4380 4759
518 656 201 494 186 712
378 301 367 274 11197 11268
584 827 235 406 17966 20618
229 110 178 821 8434 10373
305 985 471 874 5985 6773
498 934 494 196 8041 9245
316 274 787 308 5261 6548
200 3 212 615 19915 21624
405 734 181 765 21645 22247
78 559 207 429 9314 9991
73 801 159 839 21238 21389
684 642 427 476 8629 9198
324 207 432 878 21551 23406
662 421 314 445 281 656
506 215 254 27 15739 16744
426 564 793 337 12562 13647
144 703 519 468 13832 15642
323 264 567 428 17801 18318
92 949 494 860 10996 12406
365 480 606 828 21894 23213
367 597 298 4 10403 12129
544 27 50 758 18105 20470
187 940 705 485 12443 13461
657 187 799 894 10418 12122
727 896 348 523 7740 9361
268 768 376 617 3434 4340
424 969 700 870 23612 24299
6 455 131 145 17131 18161
227 816 658 454 1639 4215
182 183 600 283 18134 18995
534 379 563 43 20940 21378
171 247 177 833 20010 20869
461 731 626 680 12980 13727
481 487 452 191 11746 12251
345 370 559 458 17768 18276
212 48 83 988 20656 22952
787 556 533 18 23346 24893
766 849 142 568 12736 13809
70 960 521 212 3311 5812
517 208 599 956 4124 6414
115 955 198 643 6861 7483
245 963 300 523 21132 22726
87 827 77 946 6638 7001
757 681 714 387 18373 18879
495 147 33 768 17861 20391
125 217 373 584 18068 19897
484 871 376 848 7160 7457
557 342 412 325 12386 12833
618 558 373 771 14644 15166
416 812 386 824 21993 22127
715 879 347 44 11544 14794
583 59 384 785 21677 23582
426 66 420 751 5697 7490
505 566 462 286 24060 24865
586 708 407 878 1409 2365
591 639 361 143 4166 5710
597 94 414 473 9045 10227
310 10 183 153 22991 23751
224 842 511 752 21285 22475
774 580 750 449 19730 20195
20 131 10 783 9134 10135
695 831 187 311 9634 13086
400 136 569 558 15534 16941
250 700 775 980 10030 10984
595 862 798 67 5978 8121
269 492 252 561 3412 3577
511 975 61 830 16361 17811
432 268 46 910 20167 21514
768 283 770 992 18656 19419
285 20 605 565 5193 8091
402 665 534 695 17202 17416
635 475 512 992 18217 19244
264 906 722 289 22325 23566
91 482 772 430 2956 4966
561 555 125 269 11932 13489
3 203 346 877 721 3756
606 724 154 616 20196 21068
463 972 343 532 13263 14196
71 674 33 713 3467 3562
"""


import timeit
from sys import stdin

start = timeit.default_timer()

lines = [x for x in myInput.split('\n')]

R, C, F, N, B, T = [int(x) for x in lines[0].split()]

inRideTbl = []

for i in range(1, N+1):
    inRideTbl.append([int(x) for x in lines[i].split()])

print (inRideTbl)

## create vehicle table list
vehicleTable = []
for i in range(F):
    vehicleTable.append([False, [0, 0], 0, False, []])     #Vechile on Ride, curent ride finish POS, next no of Steps to be Occupied, (Ride ID) else False, Ride taken Seq list

## create ride table list

rideTable = []
for i in range(N):
    rideTable.append([False, False, False, 0])   #Ride assigned, Ride completed, Started on Time, Ride distance

def printTable():
    print ("-----------------------")
    print (vehicleTable)
    print (rideTable)

def calculatePoints():
    points = 0
    
    for ride in rideTable:
        if ride[1] == True:
            points += ride[3]
            
            if ride[2] == True:
                points += B
    
    print ("-----------------------")
    print ("Points", points)
    
    #for vehicle in vehicleTable:
        #print (len(vehicle[4]), vehicle[4])
    
printTable()

def findClosestRide(vehicle, step):     # find ride for current vehicle out of available rides which has closest start from vehicle's current position
    closestRideDistance = T
    closestRideIndex = None
    
    for iR, ride in enumerate(rideTable):
        if (ride[0] == False) and (step < inRideTbl[iR][5]):   #ride is not assigned and assign ride to vehicle if "current step" less "latest finish"
            vehicleToStartDistance = abs(vehicle[1][0] - inRideTbl[iR][0]) + abs(vehicle[1][1] - inRideTbl[iR][1])
            
            if (inRideTbl[iR][4] - (vehicleToStartDistance + step)) <= closestRideDistance:
                closestRideDistance = (inRideTbl[iR][4] - (vehicleToStartDistance + step))
                closestRideIndex = iR

    return closestRideIndex
    

############# logic

for step in range(T):
    for iV, vehicle in enumerate(vehicleTable):
        if vehicle[0] == False :    #vehicle is not assigned
        
            iR = findClosestRide(vehicle, step)
            
            if iR != None:
                ride = rideTable[iR]
                        
                vehicle[0] = True
                vehicle[3] = iR
                ride[0] = True
                
                rideDistance = abs(inRideTbl[iR][0] - inRideTbl[iR][2]) + abs(inRideTbl[iR][1] - inRideTbl[iR][3])
                vehicleToStartDistance = abs(vehicle[1][0] - inRideTbl[iR][0]) + abs(vehicle[1][1] - inRideTbl[iR][1])
                
                vehicle[2] = rideDistance + inRideTbl[iR][4] + vehicleToStartDistance
                
                vehicle[1] = [inRideTbl[iR][2], inRideTbl[iR][3]]
                
                vehicle[4].append(iR)
                
                if (step + vehicleToStartDistance) <= inRideTbl[iR][4]:        # ride started on time
                    ride[2] = True
                
                ride[3] = rideDistance
                
                print ("Step:", step, "Vehicle:", iV, "has Ride:", iR)
                
        else:   #vehicle is assigned 
            
            #reduce "next no of Steps to be Occupied" by one step for that vehicle
            vehicle[2] -= 1
            
            if vehicle[2] == 0:    #check if ride is finishing then reset vehicle and complete the Ride flag
                rideTable[vehicle[3]][1] = True
                vehicle[0] = False
                vehicle[3] = False
                
printTable()
calculatePoints()

print ('Time:', round(timeit.default_timer() - start, 5), "seconds.")
# Out:
# [[395, 43, 296, 955, 244, 3620], [734, 467, 300, 833, 21919, 23595], [473, 815, 21, 810, 24428, 24959], [210, 150, 387, 12, 12646, 13491], [314, 563, 141, 419, 2744, 3381], [237, 432, 151, 805, 16506, 17940], [264, 491, 445, 767, 14518, 16078], [219, 215, 154, 449, 2806, 3698], [508, 681, 180, 701, 2744, 3179], [460, 585, 320, 715, 23246, 23518], [732, 600, 101, 985, 15613, 19024], [790, 935, 686, 121, 12617, 14630], [761, 85, 111, 567, 18517, 21011], [126, 185, 470, 739, 4056, 5036], [31, 325, 197, 802, 11368, 12202], [190, 614, 588, 972, 5453, 7904], [493, 783, 48, 358, 16842, 18899], [648, 494, 602, 487, 20154, 20301], [108, 973, 280, 646, 6209, 7780], [81, 766, 536, 544, 7102, 7835], [547, 716, 490, 315, 17725, 18263], [498, 128, 223, 589, 8084, 9741], [593, 508, 380, 466, 13853, 14535], [368, 900, 100, 744, 13935, 15080], [219, 277, 244, 256, 3766, 3905], [292, 766, 393, 28, 15583, 17315], [621, 39, 399, 117, 12206, 13006], [62, 406, 534, 169, 12669, 14289], [550, 693, 454, 379,
# ...
